# %% [markdown]
# --- Day 3: Binary Diagnostic ---
# The submarine has been making some odd creaking noises, so you ask it to produce a diagnostic report just in case.
#
# The diagnostic report (your puzzle input) consists of a list of binary numbers which, when decoded properly, can tell you many useful things about the conditions of the submarine. The first parameter to check is the power consumption.
#
# You need to use the binary numbers in the diagnostic report to generate two new binary numbers (called the gamma rate and the epsilon rate). The power consumption can then be found by multiplying the gamma rate by the epsilon rate.
#
# Each bit in the gamma rate can be determined by finding the most common bit in the corresponding position of all numbers in the diagnostic report. For example, given the following diagnostic report:
#
# 00100
#
# 11110
#
# 10110
#
# 10111
#
# 10101
#
# 01111
#
# 00111
#
# 11100
#
# 10000
#
# 11001
#
# 00010
#
# 01010
#
# Considering only the first bit of each number, there are five 0 bits and seven 1 bits. Since the most common bit is 1, the first bit of the gamma rate is 1.
#
# The most common second bit of the numbers in the diagnostic report is 0, so the second bit of the gamma rate is 0.
#
# The most common value of the third, fourth, and fifth bits are 1, 1, and 0, respectively, and so the final three bits of the gamma rate are 110.
#
# So, the gamma rate is the binary number 10110, or 22 in decimal.
#
# The epsilon rate is calculated in a similar way; rather than use the most common bit, the least common bit from each position is used. So, the epsilon rate is 01001, or 9 in decimal. Multiplying the gamma rate (22) by the epsilon rate (9) produces the power consumption, 198.
#
# Use the binary numbers in your diagnostic report to calculate the gamma rate and epsilon rate, then multiply them together. What is the power consumption of the submarine? (Be sure to represent your answer in decimal, not binary.)

# %%
with open('day3_puzzle_input.txt') as fp:
    line = fp.readline().strip()
    list = []
    while line:
        list.append(line)
        line = fp.readline().strip()

highest_frequency = ""
lowest_frequency = ""
frequency = 0
for i in range(len(list[0])):
    for j in range(len(list)):
        frequency = frequency + int(list[j][i])
    if frequency - (len(list) / 2) < 0:
        highest_frequency = highest_frequency + '0'
    else:
        highest_frequency = highest_frequency + '1'

    if frequency - (len(list) / 2) < 0:
        lowest_frequency = lowest_frequency + '1'
    else:
        lowest_frequency = lowest_frequency + '0'
    frequency = 0

def binary_conversion(num):
    decimal_number = 0
    for i in range(1,len(num)+1):
        decimal_number = decimal_number + int(num[-i])*(2**(i-1))
    return decimal_number

gamma_rate = binary_conversion(highest_frequency)
episilon_rate = binary_conversion(lowest_frequency)


power_consumption = gamma_rate * episilon_rate

print(f"Power consumption of submarine is {power_consumption}.")
# Out:
# Power consumption of submarine is 4191876.

# %%
with open('day3_puzzle_input.txt') as fp:
    line = fp.readline().strip()
    list = []
    while line:
        list.append(line)
        line = fp.readline().strip()

highest_frequency = []
lowest_frequency = []
oxygen_gen_rating = list.copy()
co2_scrub_rating = list.copy()
frequency = 0

for i in range(len(oxygen_gen_rating[0])):
    for j in range(len(oxygen_gen_rating)):
        frequency = frequency + int(oxygen_gen_rating[j][i])
    
    if frequency - (len(oxygen_gen_rating)/2) >= 0:
        highest_frequency = ['1']
    else:
        highest_frequency = ['0']
    
    frequency = 0
    tmp_list1 = []
    for k in range(len(oxygen_gen_rating)):
        if highest_frequency[0] in oxygen_gen_rating[k][i]:
            tmp_list1.append(oxygen_gen_rating[k])
    oxygen_gen_rating = tmp_list1.copy()

    if len(oxygen_gen_rating) == 1:
        break

for i in range(len(co2_scrub_rating[0])):
    for j in range(len(co2_scrub_rating)):
        frequency = frequency + int(co2_scrub_rating[j][i])
    
    if frequency - (len(co2_scrub_rating)/2) >= 0:
        lowest_frequency = ['0']
    else:
        lowest_frequency = ['1']
    
    frequency = 0
    tmp_list1 = []
    for k in range(len(co2_scrub_rating)):
        if lowest_frequency[0] in co2_scrub_rating[k][i]:
            tmp_list1.append(co2_scrub_rating[k])
    co2_scrub_rating = tmp_list1.copy()

    if len(co2_scrub_rating) == 1:
        break

o2_level = binary_conversion(oxygen_gen_rating[0])
co2_level = binary_conversion(co2_scrub_rating[0])

life_support_rating = o2_level * co2_level
print(life_support_rating)
# Out:
# 3414905
